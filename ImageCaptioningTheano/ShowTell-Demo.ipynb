# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import urllib2, os, tempfile
from scipy.misc import imread


def image_from_url(url):
    try:
        f = urllib2.urlopen(url)
        _, fname = tempfile.mkstemp()
        with open(fname, 'wb') as ff:
            ff.write(f.read())
        img = imread(fname)
        os.remove(fname)
        return img
    except urllib2.URLError as e:
        print('URL Error: ', e.reason, url)
    except urllib2.HTTPError as e:
        print('HTTP Error:', e.code, url)

# %% [markdown]
# ## Test1

# %%
url_image = 'http://farm8.staticflickr.com/7333/10045949924_865301c2bb_z.jpg'

plt.imshow(image_from_url(url_image))
plt.show()

# %% [markdown]
# #### Caption output: a kitchen with a UNK in the corner of a UNK kitchen

# %% [markdown]
# ## Test 2

# %%
url_image = 'http://farm2.staticflickr.com/1226/686014029_426aa44a79_z.jpg'

plt.imshow(image_from_url(url_image))
plt.show()

# %% [markdown]
# #### Caption output: a table topped with UNK and pink flowers

# %% [markdown]
# ## Test 3

# %%
url_image = 'http://farm8.staticflickr.com/7062/6972838001_b18373e2aa_z.jpg'

plt.imshow(image_from_url(url_image))
plt.show()

# %% [markdown]
# #### Caption output: a pair of giraffes standing next to a building

# %% [markdown]
# ## Test 4

# %%
url_image = 'http://farm6.staticflickr.com/5100/5512975978_17f7d83f22_z.jpg'

plt.imshow(image_from_url(url_image))
plt.show()

# %% [markdown]
# #### Caption output: a man standing next to a bench in front of a lake

# %% [markdown]
# ## Test 5

# %%
url_image = 'http://farm5.staticflickr.com/4147/5092950439_ddb24c3b23_z.jpg'

plt.imshow(image_from_url(url_image))
plt.show()

# %% [markdown]
# #### Caption output: a black cat is sitting next to a bench

# %% [markdown]
# ## Test 6

# %%
url_image = 'http://farm4.staticflickr.com/3665/9421146797_91b3ba955d_z.jpg'

plt.imshow(image_from_url(url_image))
plt.show()

# %% [markdown]
# #### Caption output: a man riding a skate board in the air

# %% [markdown]
# ## Test 7

# %%
url_image = 'http://farm8.staticflickr.com/7428/9952990185_bed38813d6_z.jpg'

plt.imshow(image_from_url(url_image))
plt.show()

# %% [markdown]
# #### Caption output: a public transit bus on a UNK in the city

# %% [markdown]
# ## Testing our images

# %%
import matplotlib.image as mpimg

url = "../../data/random_test_data/Family_2.jpg"

image = mpimg.imread(url)
plt.imshow(image)
plt.show()

# %% [markdown]
# #### Caption output: a man sitting on a bench on a sidewalk

# %%
url = "../../data/random_test_data/Family_1.jpg"

image = mpimg.imread(url)
plt.imshow(image)
plt.show()

# %% [markdown]
# #### Caption output: a little girl sitting next to a brown horse
#
#
# In this case, it is so smart. It recognized my son as a brown horse - in 12 zodiac, my son birth year was horse. It praised my wife as a little girl.
#
# What a machine!
